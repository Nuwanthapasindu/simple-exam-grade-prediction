# %% [markdown]
# <a href="https://colab.research.google.com/github/Nuwanthapasindu/simple-exam-grade-prediction/blob/main/Student_grade_predictor.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd

# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
import matplotlib.pyplot as plt

# %%
path =  "drive/MyDrive/ML_Learning/StudetGradePredictor/dataset.csv"

# %%
data = pd.read_csv(path)

# %%
data.head()
# Out:
#    mark grade
# 0    85     A
# 1    42    C-
# 2    77    A-
# 3    91    A+
# 4    65     B

# %%
x = data[['mark']]
y = data['grade']

# %%
y.value_counts()
# Out:
# grade
# E     199
# A     100
# C     100
# A+    100
# A-     50
# C-     50
# B-     50
# B      50
# B+     50
# C+     50
# D      50
# D+     50
# Name: count, dtype: int64

# %%
grade_list = y.unique()
grade_list
# Out:
# array(['A', 'C-', 'A-', 'A+', 'B', 'C', 'B-', 'B+', 'C+', 'D', 'D+', 'E'],
#       dtype=object)

# %%
# Check if the 'grade' column exists before attempting to map
if 'grade' in data.columns:
    # Create a dictionary mapping grades to numerical indices
    grade_map = {grade: index + 1 for index, grade in enumerate(grade_list)}

    # Apply the mapping to the 'grade' column
    data['grade_encoded'] = data['grade'].map(grade_map).fillna(0).astype(int)

    # You can now use 'grade_encoded' for tasks requiring numerical representation
else:
    print("The 'grade' column does not exist in the DataFrame.")
    # You might want to handle this case, e.g., by recreating the 'grade' column if needed.

# %%
data.head(10)
# Out:
#    mark grade  grade_encoded
# 0    85     A              1
# 1    42    C-              2
# 2    77    A-              3
# 3    91    A+              4
# 4    65     B              5
# 5    53     C              6
# 6    78    A-              3
# 7    95    A+              4
# 8    48     C              6
# 9    61    B-              7

# %%
data.pop('grade')
# Out:
# 0       A
# 1      C-
# 2      A-
# 3      A+
# 4       B
#        ..
# 894     E
# 895     E
# 896     E
# 897     E
# 898     E
# Name: grade, Length: 899, dtype: object

# %%
data.head()
# Out:
#    mark  grade_encoded
# 0    85              1
# 1    42              2
# 2    77              3
# 3    91              4
# 4    65              5

# %%
y = data['grade_encoded']

# %%
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.2)

# %%
x_train
# Out:
#      mark
# 597    33
# 768    86
# 785    43
# 329    33
# 344    23
# ..    ...
# 419    46
# 75     11
# 880    25
# 781    32
# 847    59
#
# [719 rows x 1 columns]

# %%
y_train
# Out:
# 597    10
# 768     1
# 785     2
# 329    10
# 344    12
#        ..
# 419     6
# 75     12
# 880    12
# 781    10
# 847     9
# Name: grade_encoded, Length: 719, dtype: int64

# %%
model = LogisticRegression()
model.fit(x_train, y_train)
# Out:
# /usr/local/lib/python3.11/dist-packages/sklearn/linear_model/_logistic.py:465: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. OF ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# LogisticRegression()

# %%
predict = np.floor(model.predict(x_test)).astype(int)

# %%
predict
# Out:
# array([ 3,  9,  1,  9, 10,  4, 12,  2,  8, 10,  4, 10,  3,  9,  5,  7,  4,
#        11, 11, 12,  1,  9, 10, 12,  4, 12,  2,  6,  5,  9,  9, 12, 12,  3,
#         4, 12, 12,  1,  2, 12, 12,  8,  1, 12,  3,  6, 11,  1, 12, 10, 10,
#        12,  1,  3, 12, 12,  2, 10,  1,  1,  6, 12,  6, 12, 12, 12,  8,  6,
#         1,  6,  8,  1, 12,  1,  2,  1,  9, 12,  9,  1,  1,  4,  1,  4,  1,
#         8,  6, 12, 12,  4, 12, 12, 10,  7, 12,  2,  6, 10,  7,  5,  5,  8,
#        12, 10,  1,  2, 12, 12,  5,  8,  4,  3, 12, 12, 12,  6, 12,  3,  3,
#         1, 11,  7, 10,  4,  4,  4, 12,  8, 12,  1,  3,  4, 12,  1, 12,  5,
#        12,  4, 12,  8,  4,  6,  3,  8,  6,  6,  4,  6,  6,  6, 11,  9, 12,
#         2, 10,  6,  1,  4,  3, 12,  8,  6, 10,  6,  3,  5, 12, 10,  7,  5,
#         4,  7, 10,  7,  7,  5, 10,  1,  5,  6])

# %%
y_test
# Out:
# 573     3
# 682     9
# 813     1
# 322     9
# 237    10
#        ..
# 224     5
# 787    11
# 644     1
# 568     5
# 136     6
# Name: grade_encoded, Length: 180, dtype: int64

# %%
model.score(x_test,y_test)
# Out:
# 0.9166666666666666

# %%
def predict(mark):
  predict = np.floor(model.predict([[mark]])).astype(int)
  return grade_list[predict -1]

# %%
predict(75)
# Out:
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but LogisticRegression was fitted with feature names
#   warnings.warn(
# array(['A-'], dtype=object)
